# %% [markdown]
# <a href="https://colab.research.google.com/github/251020904394-droid/trung_binh_cong/blob/main/sotrungbinhcong.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n= list(map(int, input("Nhập các số: ", ).split()))
print("Trung binh cong cac so tren la: ",sum(n)/len(n))
# Out:
# Nhập các số: 2 4 6
# Trung binh cong cac so tren la:  4.0

# %%
n=list(map(int,input("Nhap cac so:", ).split()))
a=0
for i in n:
  if i%2==0:
    a+=1
print(a)
# Out:
# Nhap cac so:2 5  3 4 6 8
# 4

# %%
n=list(map(int,input("Nhap cac so: ", ).split()))
a=max(n)
i=min(n)
print("So lon nhat: ",a)
print("So nho nhat: ",i)
# Out:
# Nhap cac so: 4 5 6 2 9 1
# So lon nhat:  9
# So nho nhat:  1

# %%
n=list(map(int,input("Nhap cac so: ",).split()))
a=sorted(n)
print("Sap xep theo thu tu lon dan: ",a)
# Out:
# Nhap cac so: 2 5 7 8 3
# Sap xep theo thu tu lon dan:  [2, 3, 5, 7, 8]

# %%
n=int(input("Nhap so can tinh: ", ))
def giai_thua(n):
    if n == 0 or n == 1:
        return 1
    else:
        return n * giai_thua(n - 1)
print(f"{n}! =", giai_thua(n)
# Out:
# Nhap so can tinh: 6
# 6! = 720

# %%
n=list(map(int,input("Nhap a va b: ",).split()))
x=0
if n[0]==0 and n[1]!=0:
  print("Phuong trinh vo nghiem")
elif n[0]==0 and n[1]==0:
  print("Phuong trinh co vo so nghiem")
else:
  x=-n[1]/n[0]
  print("Phuong trinh co mot nghiem x=",x)
# Out:
# Nhap a va b: 2 5
# Phuong trinh co mot nghiem x= -2.5
